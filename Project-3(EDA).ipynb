# %% [markdown]
# # HABERMAN'S SURVIVAL DATA    [[[EXPLONATORY DATA ANALYSIS(EDA)]]]
#
# Dataset contains cases from study condected between 1958 to 1970 at Chicago's Billings Hospital on survival of patients who had undergo surgery for BREAST CANCER
#
# ->A Dataset of Breast Cancer paticents who survivied or died after operation within 5 years.
#
# ->Instances : 306
#
# ->Attributes :4(Includind the class Attribute).
#
# ->At time of operation:-
#
#  a.Age of paticent.
#
#  b.Paticent year of operation.
#
#  c.Number of Positive axillary nodes detected.
#
#  d.Survival status(class attribute).
#    >if 1=paticent survived till 5 years or longer.
#
#    >if 2=patcient died within 5 years.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
#readind data from csv file using pandas
data=pd.read_csv("C:\\Users\\HP\\Downloads\\16.2. haberman (1).csv")

# %%
data
# Out:
#      age  year  nodes  status
# 0     30    64      1       1
# 1     30    62      3       1
# 2     30    65      0       1
# 3     31    59      2       1
# 4     31    65      4       1
# ..   ...   ...    ...     ...
# 301   75    62      1       1
# 302   76    67      0       1
# 303   77    65      3       1
# 304   78    65      1       2
# 305   83    58      2       2
#
# [306 rows x 4 columns]

# %%
#data points and features
print(data.shape)
# Out:
# (306, 4)

# %%
#column names in our dataset
print (data.columns)
# Out:
# Index(['age', 'year', 'nodes', 'status'], dtype='object')

# %%
data["status"].value_counts()
# Out:
# 1    225
# 2     81
# Name: status, dtype: int64

# %% [markdown]
# # BIVARIATE ANALYSIS
#
# # SCATTER PLOT

# %%
#2-D scatter plot:

data.plot(kind="scatter", x="age", y="year") ;
plt.show()

# %%
#Observation:- age of 40 to 70 had mostly survived

# %%
sns.set_style("whitegrid");
sns.FacetGrid(data, hue="status", size=5) \
   .map(plt.scatter, "age", "year") \
   .add_legend();
plt.show();
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
#Observation:-overlapped

# %%
sns.set_style("whitegrid");
sns.FacetGrid(data,hue="status",size=4)\
   .map(plt.scatter,"age","nodes")\
   .add_legend();
plt.show;
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
#pair scatter plot 
plt.close();
sns.set_style("whitegrid");
sns.pairplot(data, hue="status", size=2);
plt.show()
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
#Observation:- 
#1.According to age death rate lies between 30 50 age people and survival up to age80 
#2.Age and Year- age 30 to 70 had survived the most
#3.age and node- 30 to 70 age people had most surviving path
#4.year and age-mostly from 1965 to death rate increases slightly
#5.year and nodes-death rate at 0 nodes has more survival rate
#6.nodes and age-mostly survival and both are overlapped
#7.nodes and year-both are aslo overlapped
#8.As nodes decreases....survival level increases

# %% [markdown]
# # DISTRIBUTION PLOT

# %%
#Distubution plot
sns.FacetGrid(data, hue="status", size=5) \
   .map(sns.distplot, "nodes") \
   .add_legend();
plt.show();
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.FacetGrid(data, hue="status", size=5) \
   .map(sns.distplot, "year") \
   .add_legend();
plt.show();
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.FacetGrid(data, hue="status", size=5) \
   .map(sns.distplot, "age") \
   .add_legend();
plt.show();
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # UNIVARIATE ANALYSIS
#
# # CDF

# %%
data_1=data.loc[data["status"]==1]
data_2=data.loc[data["status"]==2]

# %%
counts, bin_edges = np.histogram(data_1["age"], bins=10,density = True)
pdf = counts/(sum(counts))
print(pdf);
print(bin_edges);
cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:], cdf)

plt.show();
# Out:
# [0.05333333 0.10666667 0.12444444 0.09333333 0.16444444 0.16444444
#  0.09333333 0.11111111 0.06222222 0.02666667]
# [30.  34.7 39.4 44.1 48.8 53.5 58.2 62.9 67.6 72.3 77. ]

# %%
#Observed:- in 5 ys mostly survived people are below age 70 yrs
#And mostly 50 to 60 yrs had mostyl survived in thes 5 yrs

# %%
counts, bin_edges = np.histogram(data_2['age'], bins=10,density = True)
pdf = counts/(sum(counts))
print(pdf);
print(bin_edges)
cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:], cdf)
plt.legend()

plt.show();
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# [0.03703704 0.12345679 0.19753086 0.19753086 0.13580247 0.12345679
#  0.09876543 0.04938272 0.02469136 0.01234568]
# [34.  38.9 43.8 48.7 53.6 58.5 63.4 68.3 73.2 78.1 83. ]

# %%
#conclustion: it is observed that bove 70% of people had died with in these 5 yrs ismosty equal to 60 yrs

# %%
# Plots of CDF of ages
#2
counts, bin_edges = np.histogram(data_2["age"], bins=10,density = True)
pdf = counts/(sum(counts))
print(pdf);
print(bin_edges)
cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:], cdf)
# Out:
# [0.03703704 0.12345679 0.19753086 0.19753086 0.13580247 0.12345679
#  0.09876543 0.04938272 0.02469136 0.01234568]
# [34.  38.9 43.8 48.7 53.6 58.5 63.4 68.3 73.2 78.1 83. ]

# %%
#conclustion: it is observed that bove 70% of people had died with in these 5 yrs ismosty equal to 60 yrs

# %%
counts, bin_edges = np.histogram(data_1["year"], bins=10,density = True)
pdf = counts/(sum(counts))
print(pdf);
print(bin_edges)
cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:], cdf)
# Out:
# [0.18666667 0.10666667 0.10222222 0.07111111 0.09777778 0.10222222
#  0.06666667 0.09777778 0.09333333 0.07555556]
# [58.  59.1 60.2 61.3 62.4 63.5 64.6 65.7 66.8 67.9 69. ]

# %%
#Observation: before the year 1964...62% people had survived after the operation

# %%
counts, bin_edges = np.histogram(data_2["year"], bins=10,density = True)
pdf = counts/(sum(counts))
print(pdf);
print(bin_edges);
cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:], cdf)
# Out:
# [0.25925926 0.04938272 0.03703704 0.08641975 0.09876543 0.09876543
#  0.16049383 0.07407407 0.04938272 0.08641975]
# [58.  59.1 60.2 61.3 62.4 63.5 64.6 65.7 66.8 67.9 69. ]

# %%
counts, bin_edges = np.histogram(data_1["nodes"], bins=10,density = True)
pdf = counts/(sum(counts))
print(pdf);
print(bin_edges);
cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:], cdf)
# Out:
# [0.83555556 0.08       0.02222222 0.02666667 0.01777778 0.00444444
#  0.00888889 0.         0.         0.00444444]
# [ 0.   4.6  9.2 13.8 18.4 23.  27.6 32.2 36.8 41.4 46. ]

# %%
#observation:-many people had survived having lesser nodes

# %%
counts, bin_edges = np.histogram(data_2["nodes"], bins=10,density = True)
pdf = counts/(sum(counts))
print(pdf);
print(bin_edges);
cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:], cdf)
# Out:
# [0.56790123 0.14814815 0.13580247 0.04938272 0.07407407 0.
#  0.01234568 0.         0.         0.01234568]
# [ 0.   5.2 10.4 15.6 20.8 26.  31.2 36.4 41.6 46.8 52. ]

# %% [markdown]
# # MEAN AND STANDARD DEVIATION

# %%
print("Means:")
print(np.mean(data_1["year"]))
#Mean with an outlier.
print(np.mean(np.append(data_1["year"],30)));
print(np.mean(data["year"]))

print("\nStd-dev:");
print(np.std(data_1["year"]))
print(np.std(data_2["year"]))
# Out:
# Means:
# 62.86222222222222
# 62.716814159292035
# 62.85294117647059
#
# Std-dev:
# 3.2157452144021956
# 3.3214236255207883

# %% [markdown]
# # Median,Quantiles,Percentiles,IQR

# %%
#Median, Quantiles, Percentiles, IQR.
print("\nMedians:")
print(np.median(data_1["age"]))
#Median with an outlier
print(np.median(np.append(data_1["age"],50)));
print(np.median(data_2["age"]))


print("\nQuantiles:")
print(np.percentile(data_1["age"],np.arange(0, 100, 25)))
print(np.percentile(data_2["age"],np.arange(0, 100, 25)))

print("\n90th Percentiles:")
print(np.percentile(data_1["age"],90))
print(np.percentile(data_2["age"],90))

from statsmodels import robust
print ("\nMedian Absolute Deviation")
print(robust.mad(data_1["age"]))
print(robust.mad(data_2["age"]))
# Out:
# Medians:
# 52.0
# 52.0
# 53.0
#
# Quantiles:
# [30. 43. 52. 60.]
# [34. 46. 53. 61.]
#
# 90th Percentiles:
# 67.0
# 67.0
#
# Median Absolute Deviation
# 13.343419966550417
# 11.860817748044816

# %% [markdown]
# # #Box-plot and Whiskers.

# %%
#Box-plot and Whiskers.

sns.boxplot(x='status',y='age', data=data)
plt.show()

# %%
#Observation:- Mostly above 40 and below till 60 years had survived
#and above 45 and 62 below had died

# %%
sns.boxplot(x='status',y='year', data=data)
plt.show()

# %%
#Observation:-in year wise Mostly above 60 and below till 66  years had survived
#and above 59 and 65 below had died

# %%
sns.boxplot(x='status',y='nodes', data=data)
plt.show()

# %%
#Observation:-in nodes wise having the lesser the axil nodes....the greater they survived

# %%
#violin plot

sns.violinplot(x="status", y="age", data=data, size=8)
plt.show()

# %%
#Observatiton:- overlapping is more for both plots in age wise

# %%
sns.violinplot(x="status", y="year", data=data, size=8)
plt.show()

# %%
#Observatiton:- overlapping is also more for both plots in year wise

# %%
sns.violinplot(x="status", y="nodes", data=data, size=8)
plt.show()

# %%
#Observatiton:- in node wise ....survival path is mostly equal to 0 and died path has more nodes

# %% [markdown]
# # CONCLUSION
#
# ACCORDING TO ALL THE UNIVARIATE AND BIVARIATE ANALYSIS OF HABERMAN'S SURVIVAL DATA
#
# Observation:-
#
# 2.Age and Year- age 30 to 70 had survived the most.
#
# 3.age and node- 30 to 70 age people had most surviving path.
#
# 4.year and age-mostly from 1965 to death rate increases slightly.
#
# 5.year and nodes-death rate at 0 nodes has more survival rate.
#
# 6.yearly from from 1959 to 1970 most of the survival period is arising
#
# 7.Age 40 to 70 has mostly the death rate
#
# 8.As nodes decreases....survival level increases.
#
# 9.Mean and standard deviation are mostly similar for year wise.
#
# 10.Median,Quantiles,Percentiles,IQR
